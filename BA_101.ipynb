# %% [markdown]
# <a href="https://colab.research.google.com/github/GaotheCEO/Data-analyst-101/blob/main/BA_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Day one

# %%
import pandas as pd

# %%
df = pd.read_csv(
    "./data.csv",
    encoding="ascii",
    encoding_errors="ignore"
)

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2573519523.py in <cell line: 0>()
# ----> 1 df = pd.read_csv(
#       2     "./data.csv",
#       3     encoding="ascii",
#       4     encoding_errors="ignore"
#       5 )
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df.columns

# %%
df.dtypes

# %%
#Cleanตัวที่ยังขึ้นNAอยู่

# %%
df=df.dropna(subset="type")

# %%
df['type'].isna().sum()

# %%
df.stn_code

# %%
df=df.dropna(subset="stn_code")

# %%
df['stn_code'].isna().sum()

# %%
df.tail()

# %% [markdown]
# ## Day two

# %%
import pandas as pd

# %%
df=pd.read_csv("./global_sports_footwear_sales_2018_2026.csv")
df.head()
# Out:
#     order_id  order_date   brand model_name    category  gender  size  color  \
# 0  ORD100000  2021-01-30   ASICS  Model-370     Running  Unisex     8  Black
# 1  ORD100001  2026-10-05  Reebok  Model-314   Lifestyle     Men     8   Grey
# 2  ORD100002  2023-11-12   ASICS  Model-763   Lifestyle     Men     8  Black
# 3  ORD100003  2026-08-29  Reebok  Model-905  Basketball   Women     7  White
# 4  ORD100004  2019-11-09    Nike  Model-413    Training     Men    11  Black
#
#    base_price_usd  discount_percent  final_price_usd  units_sold  revenue_usd  \
# 0             162                15           137.70           1        137.7
# 1              80                 5            76.00           3        228.0
# 2             176                15           149.60           4        598.4
# 3              61                15            51.85           2        103.7
# 4              80                 0            80.00           4        320.0
#
# ...

# %%
df=df.dropna(subset="order_date")

# %%
df.dtypes
# Out:
# order_id                  object
# order_date                object
# brand                     object
# model_name                object
# category                  object
# gender                    object
# size                       int64
# color                     object
# base_price_usd             int64
# discount_percent           int64
# final_price_usd          float64
# units_sold                 int64
# revenue_usd              float64
# payment_method            object
# sales_channel             object
# country                   object
# customer_income_level     object
# customer_rating          float64
# dtype: object

# %%
df['brand'].unique()
# Out:
# array(['ASICS', 'Reebok', 'Nike', 'New Balance', 'Adidas', 'Puma'],
#       dtype=object)

# %%
print("there are :", df["brand"].nunique())
# Out:
# there are : 6

# %%
df["brand"].value_counts()
# Out:
# brand
# ASICS          5132
# Reebok         5026
# Nike           5018
# New Balance    4982
# Puma           4924
# Adidas         4918
# Name: count, dtype: int64

# %%
df['model_name'].unique()
# Out:
# array(['Model-370', 'Model-314', 'Model-763', 'Model-905', 'Model-413',
#        'Model-158', 'Model-786', 'Model-604', 'Model-266', 'Model-876',
#        'Model-554', 'Model-661', 'Model-871', 'Model-261', 'Model-351',
#        'Model-316', 'Model-912', 'Model-747', 'Model-388', 'Model-300',
#        'Model-904', 'Model-712', 'Model-866', 'Model-991', 'Model-195',
#        'Model-270', 'Model-185', 'Model-745', 'Model-430', 'Model-732',
#        'Model-510', 'Model-212', 'Model-906', 'Model-180', 'Model-954',
#        'Model-229', 'Model-346', 'Model-393', 'Model-223', 'Model-863',
#        'Model-246', 'Model-739', 'Model-572', 'Model-996', 'Model-108',
#        'Model-251', 'Model-724', 'Model-211', 'Model-995', 'Model-780',
#        'Model-915', 'Model-121', 'Model-875', 'Model-383', 'Model-646',
#        'Model-472', 'Model-401', 'Model-260', 'Model-665', 'Model-953',
#        'Model-203', 'Model-858', 'Model-605', 'Model-611', 'Model-933',
# ...

# %%
df["model_name"].nunique()
# Out:
# 899

# %%
df['model_name'].value_counts()
# Out:
# model_name
# Model-863    53
# Model-565    51
# Model-690    51
# Model-527    48
# Model-604    48
#              ..
# Model-782    19
# Model-389    19
# Model-269    19
# Model-998    18
# Model-227    16
# Name: count, Length: 899, dtype: int64

# %%
df["model_name"].value_counts().filter(regex="^Model-86")
# Out:
# model_name
# Model-863    53
# Model-861    39
# Model-862    39
# Model-868    37
# Model-860    34
# Model-866    33
# Model-867    31
# Model-865    28
# Model-864    28
# Model-869    27
# Name: count, dtype: int64

# %%
df["brand"].value_counts().filter(regex="^A")
# Out:
# brand
# ASICS     5132
# Adidas    4918
# Name: count, dtype: int64

# %%
df["color"].value_counts().filter(regex="^B")
# Out:
# color
# Blue     5976
# Black    5972
# Name: count, dtype: int64

# %%
df["color"].value_counts().filter(regex="B")
# Out:
# color
# Blue     5976
# Black    5972
# Name: count, dtype: int64

# %% [markdown]
# Day 3

# %%
df.head()
# Out:
#     order_id  order_date   brand model_name    category  gender  size  color  \
# 0  ORD100000  2021-01-30   ASICS  Model-370     Running  Unisex     8  Black
# 1  ORD100001  2026-10-05  Reebok  Model-314   Lifestyle     Men     8   Grey
# 2  ORD100002  2023-11-12   ASICS  Model-763   Lifestyle     Men     8  Black
# 3  ORD100003  2026-08-29  Reebok  Model-905  Basketball   Women     7  White
# 4  ORD100004  2019-11-09    Nike  Model-413    Training     Men    11  Black
#
#    base_price_usd  discount_percent  final_price_usd  units_sold  revenue_usd  \
# 0             162                15           137.70           1        137.7
# 1              80                 5            76.00           3        228.0
# 2             176                15           149.60           4        598.4
# 3              61                15            51.85           2        103.7
# 4              80                 0            80.00           4        320.0
#
# ...

# %%
df.groupby('payment_method')['revenue_usd'].sum()
# Out:
# payment_method
# Bank Transfer    2346208.60
# Card             2249505.65
# Cash             2214179.15
# Wallet           2271555.05
# Name: revenue_usd, dtype: float64

# %%
df.groupby('country')['discount_percent'].mean()
# Out:
# country
# Germany     13.117825
# India       13.396113
# Pakistan    13.157405
# UAE         13.390973
# UK          13.571570
# USA         13.347921
# Name: discount_percent, dtype: float64

# %%
df.sort_values(by='base_price_usd',ascending=True)
# Out:
#         order_id  order_date        brand model_name    category  gender  \
# 17415  ORD117415  2021-04-25       Adidas  Model-830  Basketball   Women
# 3905   ORD103905  2023-08-07       Adidas  Model-108         Gym     Men
# 19878  ORD119878  2023-04-23       Adidas  Model-321  Basketball     Men
# 23659  ORD123659  2020-09-19       Reebok  Model-286  Basketball  Unisex
# 11869  ORD111869  2019-02-07  New Balance  Model-621   Lifestyle     Men
# ...          ...         ...          ...        ...         ...     ...
# 9312   ORD109312  2023-03-11         Puma  Model-958         Gym     Men
# 250    ORD100250  2021-07-09       Reebok  Model-138         Gym     Men
# 4404   ORD104404  2025-05-10         Puma  Model-819    Training     Men
# 22853  ORD122853  2019-08-05  New Balance  Model-767         Gym  Unisex
# 27886  ORD127886  2018-11-05       Adidas  Model-467    Training   Women
#
#        size  color  base_price_usd  discount_percent  final_price_usd  \
# ...

# %%
df.sort_values(by='base_price_usd',ascending=False)
# Out:
#         order_id  order_date        brand model_name    category  gender  \
# 6596   ORD106596  2019-11-22       Adidas  Model-586    Training   Women
# 6907   ORD106907  2026-06-29         Nike  Model-293    Training     Men
# 27626  ORD127626  2025-11-16         Puma  Model-631   Lifestyle     Men
# 27039  ORD127039  2019-07-13         Nike  Model-887  Basketball   Women
# 27143  ORD127143  2025-09-25  New Balance  Model-152  Basketball     Men
# ...          ...         ...          ...        ...         ...     ...
# 26653  ORD126653  2023-03-15         Puma  Model-812   Lifestyle   Women
# 5226   ORD105226  2024-04-10       Reebok  Model-507  Basketball  Unisex
# 3542   ORD103542  2023-02-03       Adidas  Model-267     Running     Men
# 6394   ORD106394  2019-07-18         Nike  Model-812  Basketball     Men
# 1023   ORD101023  2026-05-04       Adidas  Model-556     Running     Men
#
#        size  color  base_price_usd  discount_percent  final_price_usd  \
# ...

# %%
df.describe(include="all")
# Out:
#          order_id  order_date  brand model_name    category gender  \
# count       30000       30000  30000      30000       30000  30000
# unique      30000        3287      6        899           5      3
# top     ORD129983  2022-09-20  ASICS  Model-863  Basketball    Men
# freq            1          21   5132         53        6074  10075
# mean          NaN         NaN    NaN        NaN         NaN    NaN
# std           NaN         NaN    NaN        NaN         NaN    NaN
# min           NaN         NaN    NaN        NaN         NaN    NaN
# 25%           NaN         NaN    NaN        NaN         NaN    NaN
# 50%           NaN         NaN    NaN        NaN         NaN    NaN
# 75%           NaN         NaN    NaN        NaN         NaN    NaN
# max           NaN         NaN    NaN        NaN         NaN    NaN
#
#                 size  color  base_price_usd  discount_percent  \
# count   30000.000000  30000    30000.000000      30000.000000
# ...

# %%
df["units_sold"].hist(bins=4)
# Out:
# <Axes: >

# %% [markdown]
# Day 5

# %%
import pandas as pd

# %%
df=pd.read_csv("./winequality-red.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
df.sort_values(by='quality',ascending=True)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 690             7.4             1.185         0.00            4.25      0.097
# 832            10.4             0.440         0.42            1.50      0.145
# 517            10.4             0.610         0.49            2.10      0.200
# 899             8.3             1.020         0.02            3.40      0.084
# 459            11.6             0.580         0.66            2.20      0.074
# ...             ...               ...          ...             ...        ...
# 1090           10.0             0.260         0.54            1.90      0.083
# 1120            7.9             0.540         0.34            2.50      0.076
# 588             5.0             0.420         0.24            2.00      0.060
# 828             7.8             0.570         0.09            2.30      0.065
# 1549            7.4             0.360         0.30            1.80      0.074
#
# ...

# %%
df.describe(include="all")
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...
