# %% [markdown]
# <a href="https://colab.research.google.com/github/GaoTheeradet/Data-analyst-101/blob/main/Oil_price_fluctuation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/fuel_prices_1970_2026.csv")
df.head()
# Out:
#          Date  Crude_Oil_Price
# 0  1970-01-01             1.21
# 1  1970-02-01             1.21
# 2  1970-03-01             1.21
# 3  1970-04-01             1.21
# 4  1970-05-01             1.21

# %%
df.tail()
# Out:
#            Date  Crude_Oil_Price
# 670  2025-11-01            59.46
# 671  2025-12-01            57.95
# 672  2026-01-01            60.04
# 673  2026-02-01            64.47
# 674  2026-03-01            87.84

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             675 non-null    object
#  1   Crude_Oil_Price  675 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 10.7+ KB

# %%
df.sort_values(by='Crude_Oil_Price',ascending=False)
# Out:
#            Date  Crude_Oil_Price
# 462  2008-07-01       132.825184
# 461  2008-06-01       131.521111
# 460  2008-05-01       122.632609
# 506  2012-03-01       117.785000
# 629  2022-06-01       116.800000
# ..          ...              ...
# 11   1970-12-01         1.210000
# 4    1970-05-01         1.210000
# 5    1970-06-01         1.210000
# 1    1970-02-01         1.210000
# 0    1970-01-01         1.210000
#
# [675 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             675 non-null    object
#  1   Crude_Oil_Price  675 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 10.7+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
df_gaosudlor['Date'] = pd.to_datetime(df_gaosudlor['Date'])
plt.plot(df_gaosudlor['Date'], df_gaosudlor['Crude_Oil_Price'], color='red')
plt.xlabel("Date")
plt.ylabel("Crude Oil Price")
plt.title("Oil price fluctuation since 1970-2026")
plt.grid(True)
plt.show()
